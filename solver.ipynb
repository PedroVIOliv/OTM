# %%
import json
import math
import gurobipy as gp
from gurobipy import Model, GRB, quicksum

# %%
problem = 'tests/drone_problem_15.json'
with open(problem, 'r') as file:
    data = json.load(file)

# Extract data from JSON
drone_weight = data['drone_weight']
max_capacity = data['max_capacity']
battery_capacity = data['battery_capacity']
points = data['pontos']

points
# Out:
# [{'x': 195, 'y': 501, 'peso': 0},
#  {'x': 302, 'y': 550, 'peso': 10},
#  {'x': 341, 'y': 519, 'peso': 10},
#  {'x': 318, 'y': 475, 'peso': 10},
#  {'x': 358, 'y': 435, 'peso': 10},
#  {'x': 394, 'y': 483, 'peso': 10},
#  {'x': 363, 'y': 370, 'peso': 10},
#  {'x': 406, 'y': 331, 'peso': 10},
#  {'x': 459, 'y': 484, 'peso': 10},
#  {'x': 467, 'y': 348, 'peso': 10},
#  {'x': 333, 'y': 288, 'peso': 10},
#  {'x': 251, 'y': 387, 'peso': 10},
#  {'x': 275, 'y': 336, 'peso': 10},
#  {'x': 278, 'y': 273, 'peso': 10},
#  {'x': 365, 'y': 208, 'peso': 10},
#  {'x': 428, 'y': 296, 'peso': 10},
#  {'x': 195, 'y': 501, 'peso': 0}]

# %%
n = len(points) - 2  
base_start = 0
base_end = n + 1


d = {}
for i in range(len(points)):
    for j in range(len(points)):
        if i != j:
            d[i, j] = math.sqrt((points[i]['x'] - points[j]['x'])**2 + (points[i]['y'] - points[j]['y'])**2)
        else:
            d[i, j] = 0


p = {}
for i in range(1, len(points) - 1):
    p[i] = points[i]['peso']


p[base_start] = 0
p[base_end] = 0

# %%
def my_callback(model, where):
    if where == GRB.Callback.MIPSOL:  # Triggered when a new solution is found
        # Get the time since the start of optimization
        solution_time = model.cbGet(GRB.Callback.RUNTIME)
        # Retrieve the objective value of the solution
        obj_val = model.cbGet(GRB.Callback.MIPSOL_OBJ)
        
        # Store the results
        results.append({'time': solution_time, 'objective_value': obj_val})

env = gp.Env(empty=True)
env.setParam('LICENSEID', 2549422)
env.start()
model=Model('drone')
model.setParam('TimeLimit', 1800)
alpha = 1
beta = 1
x = model.addVars(len(points), len(points), vtype=GRB.BINARY, name="x")
omega = model.addVars(len(points), vtype=GRB.CONTINUOUS, name="omega")
e = model.addVars(len(points), len(points), vtype=GRB.CONTINUOUS, name="e")


#1. cada casa so vai para 1 lugar
for i in range(1, n + 1):
    model.addConstr(quicksum(x[i, j] for j in range(1, n + 2)) == 1, name=f"c1_{i}")
#2.nao vai da base para a base
model.addConstr(x[base_start, base_end] == 0, name="c2")
#3. apos voltar, nao sai
for j in range(len(points)):
    model.addConstr(x[base_end, j] == 0, name=f"c3_{j}")
#4. nao vai da casa para ela mesma
for i in range(len(points)):
    model.addConstr(x[i, i] == 0, name=f"c4_{i}")
#5. nao vai para base inicial
for i in range(len(points)):
    model.addConstr(x[i, base_start] == 0, name=f"c5_{i}")
#6. entra na base o mesmo numero de vezes que sai
model.addConstr(quicksum(x[i, base_end] for i in range(len(points))) == quicksum(x[base_start, j] for j in range(len(points))), name="c6")
#7. cada casa eh visitada 1 vez
for j in range(1, n + 1):
    model.addConstr(quicksum(x[i,j] for i in range(len(points))) == 1, name=f"c7_{j}")
#8. nenhum omega é maior que a capacidade
for i in range(len(points)):
    model.addConstr(omega[i] <= max_capacity, name=f"c8_{i}")
#9. omega da base final é o peso do drone
model.addConstr(omega[base_end] == drone_weight, name="c9")
# 10. Calculo de omega
for i in range(1, n+1):
    model.addConstr(omega[i] == p[i] + quicksum((omega[j])*x[i,j] for j in range(len(points))), name=f"c10_{i}")
# 11. Calculo de e inicial
for j in range(len(points)):
    model.addConstr(e[base_start, j] == battery_capacity - (((d[base_start, j])) * ((omega[j]) * x[base_start, j])), name=f"c11_{j}")
#12. Calculo de e
for i in range(1, n+2):
    for j in range(len(points)):
        model.addConstr(e[i, j] == quicksum(e[k,i]*x[k,i] for k in range(len(points))) - (((d[i, j])) * ((omega[j]) * x[i, j])), name=f"c12_{i}_{j}")
#13. e deve ser maior ou igual a 0
for i in range(len(points)):
    for j in range(len(points)):
        model.addConstr(e[i, j] >= 0, name=f"c13_{i}_{j}")

model.setObjective(quicksum(x[i,j] * (d[i,j]) * omega[j] for i in range(len(points)) for j in range(len(points))), GRB.MINIMIZE)

results = []

model.optimize(my_callback)
# Out:
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2549422
# Academic license 2549422 - for non-commercial use only - registered to gu___@gmail.com
# Set parameter TimeLimit to value 7200
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2549422 - for non-commercial use only - registered to gu___@gmail.com
# Optimize a model with 390 rows, 595 columns and 886 nonzeros
# Model fingerprint: 0x9d15e870
# Model has 270 quadratic objective terms
# Model has 304 quadratic constraints
# Variable types: 306 continuous, 289 integer (289 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [1e+00, 3e+02]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [8e+01, 7e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
#   QRHS range       [1e+01, 1e+08]
# Presolve removed 344 rows and 84 columns
# Presolve time: 0.00s
# Presolved: 1457 rows, 1456 columns, 7831 nonzeros
# Presolved model has 480 SOS constraint(s)
# Variable types: 976 continuous, 480 integer (480 binary)
# Found heuristic solution: objective 98481.352223
# Found heuristic solution: objective 95916.907294
#
# Root relaxation: objective 1.052167e+04, 338 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 10521.6661    0  136 95916.9073 10521.6661  89.0%     -    0s
# H    0     0                    72840.138969 10521.6661  85.6%     -    0s
#      0     0 16355.9047    0  154 72840.1390 16355.9047  77.5%     -    0s
#      0     0 18802.1783    0  169 72840.1390 18802.1783  74.2%     -    0s
#      0     0 19074.0963    0  166 72840.1390 19074.0963  73.8%     -    0s
#      0     0 20419.5171    0  183 72840.1390 20419.5171  72.0%     -    0s
# H    0     0                    67768.308957 20474.3247  69.8%     -    0s
#      0     0 20515.8458    0  192 67768.3090 20515.8458  69.7%     -    0s
#      0     0 21980.3603    0  194 67768.3090 21980.3603  67.6%     -    0s
# H    0     0                    67484.972013 21995.1183  67.4%     -    0s
#      0     0 21995.1183    0  200 67484.9720 21995.1183  67.4%     -    0s
#      0     0 22754.5175    0  192 67484.9720 22754.5175  66.3%     -    0s
#      0     0 22767.0343    0  192 67484.9720 22767.0343  66.3%     -    0s
#      0     2 22800.6789    0  192 67484.9720 22800.6789  66.2%     -    0s
# H  136   152                    66598.089524 23963.8216  64.0%  85.4    0s
# H 1904  1429                    66515.838216 36253.4577  45.5%  45.1    3s
# H 1996  1420                    65772.188187 36253.4577  44.9%  49.4    3s
#   2203  1511 infeasible   45      65772.1882 36253.4577  44.9%  52.8    5s
# H 2287  1477                    65710.957773 36289.9159  44.8%  54.7    5s
#   4150  2312 48822.4686   33  207 65710.9578 38031.1423  42.1%  62.5   10s
#   8790  5272 43164.9366   43  245 65710.9578 39745.5446  39.5%  61.2   15s
#  14693  9736 45655.3759   38  176 65710.9578 40543.8874  38.3%  57.2   20s
# H15016  9754                    65658.194860 40576.4565  38.2%  57.6   21s
# H15017  9720                    64990.783056 40576.4565  37.6%  57.6   21s
# H15018  9698                    64756.160147 40576.4565  37.3%  57.6   21s
# H16438 10678                    64151.993105 40576.4565  36.7%  57.6   24s
#  18128 11834 57785.3974   39  151 64151.9931 40791.6566  36.4%  56.7   25s
#  24149 16121 46910.5738   31  247 64151.9931 41345.3877  35.6%  55.8   30s
#  28908 19811 60810.3680   88  115 64151.9931 41737.5724  34.9%  56.4   35s
#  34694 22751 52428.0280   49  179 64151.9931 42063.1439  34.4%  55.9   40s
#  41040 27041 46057.1847   26  202 64151.9931 42373.0807  33.9%  55.6   45s
#  47986 31706 47101.4341   44  198 64151.9931 42630.8570  33.5%  55.0   50s
#  54198 35890 57289.1713   43  122 64151.9931 42852.2950  33.2%  54.5   55s
#  60277 39682 51512.2660   38  212 64151.9931 43043.9151  32.9%  54.3   60s
#  66247 43911 46867.2823   29  218 64151.9931 43207.4884  32.6%  53.8   65s
#  71930 47499 49408.7782   36  212 64151.9931 43369.1683  32.4%  53.7   70s
#  76824 50640 59525.3966   62  115 64151.9931 43527.2912  32.1%  53.5   75s
#  82853 54436 52678.4606   41  174 64151.9931 43652.6563  32.0%  53.6   80s
#  87560 57982 48593.7372   45  218 64151.9931 43751.3834  31.8%  53.5   85s
#  93580 61626 57266.9930   36   88 64151.9931 43869.2501  31.6%  53.4   90s
#  99786 65377 51845.8216   48  158 64151.9931 43995.6308  31.4%  53.2   95s
#  105955 69166     cutoff   66      64151.9931 44113.7614  31.2%  52.8  100s
#  111757 73306 59986.1659   44  149 64151.9931 44219.5487  31.1%  52.7  105s
#  117117 76314 59008.7322   39  118 64151.9931 44322.7127  30.9%  52.6  110s
#  122874 79923 61336.7899   65  160 64151.9931 44414.9523  30.8%  52.4  115s
#  127956 83172 63645.2083   47   99 64151.9931 44499.6555  30.6%  52.4  120s
#  133144 87033 45320.6904   35  223 64151.9931 44582.4862  30.5%  52.4  125s
#  138358 90459 48770.7428   38  169 64151.9931 44658.7978  30.4%  52.3  130s
#  144833 93731 50843.2508   44  175 64151.9931 44780.3315  30.2%  52.1  135s
#  150838 97455 60196.8749   38  104 64151.9931 44866.0916  30.1%  52.0  140s
#  154146 99442     cutoff   36      64151.9931 44907.0250  30.0%  52.0  145s
#  159786 103795 55897.5339   36  141 64151.9931 45000.7467  29.9%  52.0  150s
#  165437 107085 52961.5870   32  176 64151.9931 45071.9765  29.7%  51.9  155s
#  171385 110274 56673.1048   59  140 64151.9931 45151.1029  29.6%  51.8  160s
#  176758 113525 60560.8296   43  146 64151.9931 45226.2256  29.5%  51.8  165s
#  183038 117198     cutoff   53      64151.9931 45303.7256  29.4%  51.7  170s
#  189448 120957 57388.4988   50  130 64151.9931 45380.5101  29.3%  51.6  175s
#  194339 124063     cutoff   56      64151.9931 45438.9878  29.2%  51.6  180s
#  199721 128129 57618.6223   43  156 64151.9931 45496.7110  29.1%  51.5  185s
#  205787 131349 infeasible   47      64151.9931 45562.9627  29.0%  51.4  190s
#  211085 134432 infeasible   37      64151.9931 45620.9989  28.9%  51.3  195s
#  217221 138079 54883.7648   40  180 64151.9931 45693.5753  28.8%  51.3  200s
#  220210 139887 57716.8773   43  142 64151.9931 45715.2107  28.7%  51.2  741s
#  224118 142919 56477.1127   41  145 64151.9931 45748.6023  28.7%  51.2  745s
#  230758 146121 50577.8610   38  211 64151.9931 45820.2081  28.6%  51.2  750s
#  231148 146332 53189.3254   45  160 64151.9931 45821.0764  28.6%  51.2 1750s
#  236437 149551 47826.5659   34  192 64151.9931 45866.8054  28.5%  51.1 1825s
#  241379 152732 51967.1193   33  186 64151.9931 45901.9597  28.4%  51.1 1830s
#  246249 155448 50138.4894   24  221 64151.9931 45954.7541  28.4%  51.1 1835s
#  252324 158966 51189.1291   36  202 64151.9931 46012.6504  28.3%  51.0 1840s
#  258819 162859 53444.1015   51  171 64151.9931 46065.6608  28.2%  51.0 1845s
#  264465 166032 54903.3228   42  147 64151.9931 46108.4536  28.1%  51.0 1850s
#  269930 169294 57108.9202   55  131 64151.9931 46168.0018  28.0%  50.9 1855s
#  275270 172033 60430.9140   43  141 64151.9931 46210.7774  28.0%  50.9 1860s
#  280226 174898 50328.9490   33  180 64151.9931 46262.0929  27.9%  50.9 1865s
#  283659 177711 58390.1474   38  176 64151.9931 46286.6879  27.8%  50.8 1870s
# H290576 180757                    64055.876971 46346.9736  27.6%  50.8 1874s
#  290633 180924 51356.3976   35  208 64055.8770 46348.2001  27.6%  50.8 1875s
#  294253 183077 50589.5002   29  170 64055.8770 46377.0075  27.6%  50.8 1880s
#  299986 186370 55884.9116   35  155 64055.8770 46412.5891  27.5%  50.7 1885s
#  305137 190149 53657.0481   39  163 64055.8770 46458.1995  27.5%  50.7 1890s
#  311832 193468 53579.0742   31  210 64055.8770 46510.2386  27.4%  50.7 1895s
#  318163 197118 60842.0655   45  136 64055.8770 46557.3902  27.3%  50.6 1900s
#  324366 200540 47973.6070   41  199 64055.8770 46600.8271  27.2%  50.6 1905s
#  330104 204421 53617.7670   55  157 64055.8770 46640.1880  27.2%  50.5 1910s
#  336644 207709 52733.9222   48  151 64055.8770 46685.8747  27.1%  50.5 1915s
#  342099 210874 54933.1723   52  140 64055.8770 46727.2623  27.1%  50.4 1920s
#  348017 214758 53468.8420   41  185 64055.8770 46764.2823  27.0%  50.4 1925s
#  353809 217705 59300.7463   45  137 64055.8770 46807.4718  26.9%  50.3 1930s
#  358713 220937 57882.2500   54  146 64055.8770 46840.4123  26.9%  50.3 1935s
#  364767 223752 53528.1060   41  187 64055.8770 46880.4562  26.8%  50.3 1940s
#  369952 226767 52399.5045   47  141 64055.8770 46914.1939  26.8%  50.3 1945s
#  374770 229469 59792.0955   44  130 64055.8770 46941.7435  26.7%  50.3 1950s
#  380381 232850 61201.6860   65  128 64055.8770 46981.6241  26.7%  50.2 1955s
#  386837 236522 53935.6972   29  165 64055.8770 47026.1149  26.6%  50.2 1960s
#  392212 239487     cutoff   52      64055.8770 47062.1132  26.5%  50.2 1965s
#  397359 242326 49570.6346   25  201 64055.8770 47091.3727  26.5%  50.2 1970s
#  402767 245502 60081.3101   52  120 64055.8770 47126.0380  26.4%  50.1 1975s
#  407927 248508 58700.3838   51  114 64055.8770 47156.6223  26.4%  50.1 1980s
#  412737 251333 48405.5220   41  188 64055.8770 47187.5015  26.3%  50.1 1985s
#  417419 254341 56287.8702   51  119 64055.8770 47218.8222  26.3%  50.1 1990s
#  423803 257277 60824.7653   42  146 64055.8770 47256.1035  26.2%  50.1 1995s
#  429011 260112 61456.5585   44  133 64055.8770 47286.9199  26.2%  50.0 2000s
#  434721 263423 51738.9915   31  204 64055.8770 47323.2123  26.1%  50.0 2005s
#  439119 265780 50449.3290   34  177 64055.8770 47349.0768  26.1%  50.0 2010s
#  444340 269388 59174.3448   45  115 64055.8770 47377.3732  26.0%  50.0 2015s
#  450327 272027 51788.3138   30  181 64055.8770 47412.3945  26.0%  50.0 2020s
#  455024 275007 61331.1919   37  130 64055.8770 47435.6776  25.9%  49.9 2025s
#  460695 277795 57120.3895   33  153 64055.8770 47471.5879  25.9%  49.9 2030s
#
# Interrupt request received
#
# Cutting planes:
#   Gomory: 49
#   Cover: 98
#   Implied bound: 234
#   MIR: 428
#   Mixing: 16
#   Flow cover: 802
#   Inf proof: 3
#   RLT: 11
#   Relax-and-lift: 46
#
# Explored 464103 nodes (23173098 simplex iterations) in 2034.28 seconds (999.36 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 64055.9 64152 64756.2 ... 67485
#
# Solve interrupted
# Best objective 6.405587697132e+04, best bound 4.748928577201e+04, gap 25.8627%
#
# User-callback calls 1142097, time in user-callback 1.00 sec

# %%
for var in model.getVars():
    if(var.x > 0):
        print(f"{var.varName} = {var.x}")


#print solution objective value
print(f"Objetivo: {model.objVal}")
# Out:
# x[0,1] = 1.0
# x[0,3] = 1.0
# x[0,6] = 1.0
# x[0,10] = 1.0
# x[0,11] = 1.0
# x[1,2] = 1.0
# x[2,4] = 1.0
# x[3,5] = 1.0
# x[4,16] = 1.0
# x[5,8] = 1.0
# x[6,7] = 1.0
# x[7,9] = 1.0
# x[8,16] = 1.0
# x[9,16] = 1.0
# x[10,14] = 1.0
# x[11,12] = 1.0
# x[12,13] = 1.0
# x[13,16] = 1.0
# x[14,15] = 1.0
# x[15,16] = 1.0
# omega[1] = 40.0
# omega[2] = 30.0
# omega[3] = 40.0
# omega[4] = 20.0
# omega[5] = 30.0
# omega[6] = 40.0
# omega[7] = 30.0
# omega[8] = 20.0
# omega[9] = 20.0
# omega[10] = 40.0
# omega[11] = 40.0
# omega[12] = 30.0
# omega[13] = 20.0
# omega[14] = 30.0
# omega[15] = 20.0
# omega[16] = 10.0
# e[0,0] = 140000000.0
# e[0,1] = 139995292.55908164
# e[0,2] = 140000000.0
# e[0,3] = 139994971.2824698
# e[0,4] = 140000000.0
# e[0,5] = 140000000.0
# e[0,6] = 139991478.497785
# e[0,7] = 140000000.0
# e[0,8] = 140000000.0
# e[0,9] = 140000000.0
# e[0,10] = 139989848.1134758
# e[0,11] = 139994919.52758104
# e[0,12] = 140000000.0
# e[0,13] = 140000000.0
# e[0,14] = 140000000.0
# e[0,15] = 140000000.0
# e[0,16] = 140000000.0
# e[1,0] = 139995292.55908164
# e[1,1] = 139995292.55908164
# e[1,2] = 139993797.96883678
# e[1,3] = 139995292.55908164
# e[1,4] = 139995292.55908164
# e[1,5] = 139995292.55908164
# e[1,6] = 139995292.55908164
# e[1,7] = 139995292.55908164
# e[1,8] = 139995292.55908164
# e[1,9] = 139995292.55908164
# e[1,10] = 139995292.55908164
# e[1,11] = 139995292.55908164
# e[1,12] = 139995292.55908164
# e[1,13] = 139995292.55908164
# e[1,14] = 139995292.55908164
# e[1,15] = 139995292.55908164
# e[1,16] = 139995292.55908164
# e[2,0] = 139993797.96883678
# e[2,1] = 139993797.96883678
# e[2,2] = 139993797.96883678
# e[2,3] = 139993797.96883678
# e[2,4] = 139992083.9093279
# e[2,5] = 139993797.96883678
# e[2,6] = 139993797.96883678
# e[2,7] = 139993797.96883678
# e[2,8] = 139993797.96883678
# e[2,9] = 139993797.96883678
# e[2,10] = 139993797.96883678
# e[2,11] = 139993797.96883678
# e[2,12] = 139993797.96883678
# e[2,13] = 139993797.96883678
# e[2,14] = 139993797.96883678
# e[2,15] = 139993797.96883678
# e[2,16] = 139993797.96883678
# e[3,0] = 139994971.2824698
# e[3,1] = 139994971.2824698
# e[3,2] = 139994971.2824698
# e[3,3] = 139994971.2824698
# e[3,4] = 139994971.2824698
# e[3,5] = 139992678.68568885
# e[3,6] = 139994971.2824698
# e[3,7] = 139994971.2824698
# e[3,8] = 139994971.2824698
# e[3,9] = 139994971.2824698
# e[3,10] = 139994971.2824698
# e[3,11] = 139994971.2824698
# e[3,12] = 139994971.2824698
# e[3,13] = 139994971.2824698
# e[3,14] = 139994971.2824698
# e[3,15] = 139994971.2824698
# e[3,16] = 139994971.2824698
# e[4,0] = 139992083.9093279
# e[4,1] = 139992083.9093279
# e[4,2] = 139992083.9093279
# e[4,3] = 139992083.9093279
# e[4,4] = 139992083.9093279
# e[4,5] = 139992083.9093279
# e[4,6] = 139992083.9093279
# e[4,7] = 139992083.9093279
# e[4,8] = 139992083.9093279
# e[4,9] = 139992083.9093279
# e[4,10] = 139992083.9093279
# e[4,11] = 139992083.9093279
# e[4,12] = 139992083.9093279
# e[4,13] = 139992083.9093279
# e[4,14] = 139992083.9093279
# e[4,15] = 139992083.9093279
# e[4,16] = 139990325.3587884
# e[5,0] = 139992678.68568885
# e[5,1] = 139992678.68568885
# e[5,2] = 139992678.68568885
# e[5,3] = 139992678.68568885
# e[5,4] = 139992678.68568885
# e[5,5] = 139992678.68568885
# e[5,6] = 139992678.68568885
# e[5,7] = 139992678.68568885
# e[5,8] = 139991378.5318518
# e[5,9] = 139992678.68568885
# e[5,10] = 139992678.68568885
# e[5,11] = 139992678.68568885
# e[5,12] = 139992678.68568885
# e[5,13] = 139992678.68568885
# e[5,14] = 139992678.68568885
# e[5,15] = 139992678.68568885
# e[5,16] = 139992678.68568885
# e[6,0] = 139991478.497785
# e[6,1] = 139991478.497785
# e[6,2] = 139991478.497785
# e[6,3] = 139991478.497785
# e[6,4] = 139991478.497785
# e[6,5] = 139991478.497785
# e[6,6] = 139991478.497785
# e[6,7] = 139989736.94675216
# e[6,8] = 139991478.497785
# e[6,9] = 139991478.497785
# e[6,10] = 139991478.497785
# e[6,11] = 139991478.497785
# e[6,12] = 139991478.497785
# e[6,13] = 139991478.497785
# e[6,14] = 139991478.497785
# e[6,15] = 139991478.497785
# e[6,16] = 139991478.497785
# e[7,0] = 139989736.94675216
# e[7,1] = 139989736.94675216
# e[7,2] = 139989736.94675216
# e[7,3] = 139989736.94675216
# e[7,4] = 139989736.94675216
# e[7,5] = 139989736.94675216
# e[7,6] = 139989736.94675216
# e[7,7] = 139989736.94675216
# e[7,8] = 139989736.94675216
# e[7,9] = 139988470.45553625
# e[7,10] = 139989736.94675216
# e[7,11] = 139989736.94675216
# e[7,12] = 139989736.94675216
# e[7,13] = 139989736.94675216
# e[7,14] = 139989736.94675216
# e[7,15] = 139989736.94675216
# e[7,16] = 139989736.94675216
# e[8,0] = 139991378.5318518
# e[8,1] = 139991378.5318518
# e[8,2] = 139991378.5318518
# e[8,3] = 139991378.5318518
# e[8,4] = 139991378.5318518
# e[8,5] = 139991378.5318518
# e[8,6] = 139991378.5318518
# e[8,7] = 139991378.5318518
# e[8,8] = 139991378.5318518
# e[8,9] = 139991378.5318518
# e[8,10] = 139991378.5318518
# e[8,11] = 139991378.5318518
# e[8,12] = 139991378.5318518
# e[8,13] = 139991378.5318518
# e[8,14] = 139991378.5318518
# e[8,15] = 139991378.5318518
# e[8,16] = 139988733.06402928
# e[9,0] = 139988470.45553625
# e[9,1] = 139988470.45553625
# e[9,2] = 139988470.45553625
# e[9,3] = 139988470.45553625
# e[9,4] = 139988470.45553625
# e[9,5] = 139988470.45553625
# e[9,6] = 139988470.45553625
# e[9,7] = 139988470.45553625
# e[9,8] = 139988470.45553625
# e[9,9] = 139988470.45553625
# e[9,10] = 139988470.45553625
# e[9,11] = 139988470.45553625
# e[9,12] = 139988470.45553625
# e[9,13] = 139988470.45553625
# e[9,14] = 139988470.45553625
# e[9,15] = 139988470.45553625
# e[9,16] = 139985349.67037863
# e[10,0] = 139989848.1134758
# e[10,1] = 139989848.1134758
# e[10,2] = 139989848.1134758
# e[10,3] = 139989848.1134758
# e[10,4] = 139989848.1134758
# e[10,5] = 139989848.1134758
# e[10,6] = 139989848.1134758
# e[10,7] = 139989848.1134758
# e[10,8] = 139989848.1134758
# e[10,9] = 139989848.1134758
# e[10,10] = 139989848.1134758
# e[10,11] = 139989848.1134758
# e[10,12] = 139989848.1134758
# e[10,13] = 139989848.1134758
# e[10,14] = 139987263.23436838
# e[10,15] = 139989848.1134758
# e[10,16] = 139989848.1134758
# e[11,0] = 139994919.52758104
# e[11,1] = 139994919.52758104
# e[11,2] = 139994919.52758104
# e[11,3] = 139994919.52758104
# e[11,4] = 139994919.52758104
# e[11,5] = 139994919.52758104
# e[11,6] = 139994919.52758104
# e[11,7] = 139994919.52758104
# e[11,8] = 139994919.52758104
# e[11,9] = 139994919.52758104
# e[11,10] = 139994919.52758104
# e[11,11] = 139994919.52758104
# e[11,12] = 139993228.58110052
# e[11,13] = 139994919.52758104
# e[11,14] = 139994919.52758104
# e[11,15] = 139994919.52758104
# e[11,16] = 139994919.52758104
# e[12,0] = 139993228.58110052
# e[12,1] = 139993228.58110052
# e[12,2] = 139993228.58110052
# e[12,3] = 139993228.58110052
# e[12,4] = 139993228.58110052
# e[12,5] = 139993228.58110052
# e[12,6] = 139993228.58110052
# e[12,7] = 139993228.58110052
# e[12,8] = 139993228.58110052
# e[12,9] = 139993228.58110052
# e[12,10] = 139993228.58110052
# e[12,11] = 139993228.58110052
# e[12,12] = 139993228.58110052
# e[12,13] = 139991967.15333802
# e[12,14] = 139993228.58110052
# e[12,15] = 139993228.58110052
# e[12,16] = 139993228.58110052
# e[13,0] = 139991967.15333802
# e[13,1] = 139991967.15333802
# e[13,2] = 139991967.15333802
# e[13,3] = 139991967.15333802
# e[13,4] = 139991967.15333802
# e[13,5] = 139991967.15333802
# e[13,6] = 139991967.15333802
# e[13,7] = 139991967.15333802
# e[13,8] = 139991967.15333802
# e[13,9] = 139991967.15333802
# e[13,10] = 139991967.15333802
# e[13,11] = 139991967.15333802
# e[13,12] = 139991967.15333802
# e[13,13] = 139991967.15333802
# e[13,14] = 139991967.15333802
# e[13,15] = 139991967.15333802
# e[13,16] = 139989540.77743968
# e[14,0] = 139987263.23436838
# e[14,1] = 139987263.23436838
# e[14,2] = 139987263.23436838
# e[14,3] = 139987263.23436838
# e[14,4] = 139987263.23436838
# e[14,5] = 139987263.23436838
# e[14,6] = 139987263.23436838
# e[14,7] = 139987263.23436838
# e[14,8] = 139987263.23436838
# e[14,9] = 139987263.23436838
# e[14,10] = 139987263.23436838
# e[14,11] = 139987263.23436838
# e[14,12] = 139987263.23436838
# e[14,13] = 139987263.23436838
# e[14,14] = 139987263.23436838
# e[14,15] = 139985098.70208633
# e[14,16] = 139987263.23436838
# e[15,0] = 139985098.70208633
# e[15,1] = 139985098.70208633
# e[15,2] = 139985098.70208633
# e[15,3] = 139985098.70208633
# e[15,4] = 139985098.70208633
# e[15,5] = 139985098.70208633
# e[15,6] = 139985098.70208633
# e[15,7] = 139985098.70208633
# e[15,8] = 139985098.70208633
# e[15,9] = 139985098.70208633
# e[15,10] = 139985098.70208633
# e[15,11] = 139985098.70208633
# e[15,12] = 139985098.70208633
# e[15,13] = 139985098.70208633
# e[15,14] = 139985098.70208633
# e[15,15] = 139985098.70208633
# e[15,16] = 139981995.25239283
# e[16,0] = 699935944.1230288
# e[16,1] = 699935944.1230288
# e[16,2] = 699935944.1230288
# e[16,3] = 699935944.1230288
# e[16,4] = 699935944.1230288
# e[16,5] = 699935944.1230288
# e[16,6] = 699935944.1230288
# e[16,7] = 699935944.1230288
# e[16,8] = 699935944.1230288
# e[16,9] = 699935944.1230288
# e[16,10] = 699935944.1230288
# e[16,11] = 699935944.1230288
# e[16,12] = 699935944.1230288
# e[16,13] = 699935944.1230288
# e[16,14] = 699935944.1230288
# e[16,15] = 699935944.1230288
# e[16,16] = 699935944.1230288
# Objetivo: 64055.876971319405

# %%
subroutes = []
goesTo = {}

for var in model.getVars():
    if var.VarName[0] == 'x' and var.x > 0:
        #print(f"{var.VarName} = {var.x}")
        x,y = var.VarName.split('[')[1].split(']')[0].split(',')
        x = int(x)
        y = int(y)
        if x == base_start:
            subroutes.append([y])
        else:
            goesTo[x] = y

for i in range(len(subroutes)):
    next = goesTo[subroutes[i][-1]]
    while next != base_end:
        subroutes[i].append(next)
        next = goesTo[next]

print(subroutes)
route = []
for subroute in subroutes:
    route += subroute
    route.append(0)
route.pop()
print(route)
print(model.ObjVal)
# Out:
# [[1, 2, 4], [3, 5, 8], [6, 7, 9], [10, 14, 15], [11, 12, 13]]
# [1, 2, 4, 0, 3, 5, 8, 0, 6, 7, 9, 0, 10, 14, 15, 0, 11, 12, 13]
# 64055.876971319405

# %%
solution_count = model.SolCount
solve_json = {}
problem_name = problem.split('/')[1].split('.')[0]
with open(f"results/solved_{problem_name}.json", 'w') as file:
    json.dump(results, file)

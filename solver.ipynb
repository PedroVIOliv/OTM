# %%
import json
import math
import gurobipy as gp
from gurobipy import Model, GRB, quicksum

# %%
problem = 'tests/drone_problem_23.json'
with open(problem, 'r') as file:
    data = json.load(file)

# Extract data from JSON
drone_weight = data['drone_weight']
max_capacity = data['max_capacity']
battery_capacity = data['battery_capacity']
points = data['pontos']

points
# Out:
# [{'x': 195, 'y': 501, 'peso': 0},
#  {'x': 302, 'y': 550, 'peso': 10},
#  {'x': 341, 'y': 519, 'peso': 10},
#  {'x': 318, 'y': 475, 'peso': 10},
#  {'x': 358, 'y': 435, 'peso': 10},
#  {'x': 394, 'y': 483, 'peso': 10},
#  {'x': 390, 'y': 402, 'peso': 10},
#  {'x': 307, 'y': 384, 'peso': 10},
#  {'x': 363, 'y': 370, 'peso': 10},
#  {'x': 406, 'y': 331, 'peso': 10},
#  {'x': 459, 'y': 410, 'peso': 10},
#  {'x': 459, 'y': 484, 'peso': 10},
#  {'x': 467, 'y': 348, 'peso': 10},
#  {'x': 333, 'y': 288, 'peso': 10},
#  {'x': 240, 'y': 316, 'peso': 10},
#  {'x': 251, 'y': 387, 'peso': 10},
#  {'x': 275, 'y': 336, 'peso': 10},
#  {'x': 225, 'y': 223, 'peso': 10},
#  {'x': 278, 'y': 273, 'peso': 10},
#  {'x': 365, 'y': 208, 'peso': 10},
#  {'x': 428, 'y': 296, 'peso': 10},
#  {'x': 517, 'y': 219, 'peso': 10},
#  {'x': 487, 'y': 278, 'peso': 10},
#  {'x': 166, 'y': 270, 'peso': 10},
#  {'x': 195, 'y': 501, 'peso': 0}]

# %%
n = len(points) - 2  
base_start = 0
base_end = n + 1


d = {}
for i in range(len(points)):
    for j in range(len(points)):
        if i != j:
            d[i, j] = math.sqrt((points[i]['x'] - points[j]['x'])**2 + (points[i]['y'] - points[j]['y'])**2)
        else:
            d[i, j] = 0


p = {}
for i in range(1, len(points) - 1):
    p[i] = points[i]['peso']


p[base_start] = 0
p[base_end] = 0

# %%
env = gp.Env(empty=True)
env.setParam('LICENSEID', 2548345)
env.start()
model=Model('drone')
model.setParam('TimeLimit', 500)
alpha = 1
beta = 1
x = model.addVars(len(points), len(points), vtype=GRB.BINARY, name="x")
omega = model.addVars(len(points), vtype=GRB.CONTINUOUS, name="omega")
e = model.addVars(len(points), len(points), vtype=GRB.CONTINUOUS, name="e")
omega_power_beta = model.addVars(len(points), vtype=GRB.CONTINUOUS, name="omega_power_beta")

for i in range(len(points)):
    model.addGenConstrPow(omega[i], omega_power_beta[i], beta, "gc")

#1. cada casa so vai para 1 lugar
for i in range(1, n + 1):
    model.addConstr(quicksum(x[i, j] for j in range(1, n + 2)) == 1, name=f"c1_{i}")
#2.nao vai da base para a base
model.addConstr(x[base_start, base_end] == 0, name="c2")
#3. apos voltar, nao sai
for j in range(len(points)):
    model.addConstr(x[base_end, j] == 0, name=f"c3_{j}")
#4. nao vai da casa para ela mesma
for i in range(len(points)):
    model.addConstr(x[i, i] == 0, name=f"c4_{i}")
#5. nao vai para base inicial
for i in range(len(points)):
    model.addConstr(x[i, base_start] == 0, name=f"c5_{i}")
#6. entra na base o mesmo numero de vezes que sai
model.addConstr(quicksum(x[i, base_end] for i in range(len(points))) == quicksum(x[base_start, j] for j in range(len(points))), name="c6")
#7. cada casa eh visitada 1 vez
for j in range(1, n + 1):
    model.addConstr(quicksum(x[i,j] for i in range(len(points))) == 1, name=f"c7_{j}")
#8. nenhum omega é maior que a capacidade
for i in range(len(points)):
    model.addConstr(omega[i] <= max_capacity, name=f"c8_{i}")
#9. omega da base final é o peso do drone
model.addConstr(omega[base_end] == drone_weight, name="c9")
# 10. Calculo de omega
for i in range(1, n+1):
    model.addConstr(omega[i] == p[i] + quicksum((omega[j])*x[i,j] for j in range(len(points))), name=f"c10_{i}")
# 11. Calculo de e inicial
for j in range(len(points)):
    model.addConstr(e[base_start, j] == battery_capacity - (((d[base_start, j]) ** alpha) * ((omega_power_beta[j]) * x[base_start, j])), name=f"c11_{j}")
#12. Calculo de e
for i in range(1, n+2):
    for j in range(len(points)):
        model.addConstr(e[i, j] == quicksum(e[k,i]*x[k,i] for k in range(len(points))) - (((d[i, j]) ** alpha) * ((omega_power_beta[j]) * x[i, j])), name=f"c12_{i}_{j}")
#13. e deve ser maior ou igual a 0
for i in range(len(points)):
    for j in range(len(points)):
        model.addConstr(e[i, j] >= 0, name=f"c13_{i}_{j}")

model.setObjective(quicksum(x[i,j] * (d[i,j] ** alpha) * omega_power_beta[j] for i in range(len(points)) for j in range(len(points))), GRB.MINIMIZE)


model.optimize()
# Out:
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2548345
# Set parameter WLSSecret
# Set parameter LicenseID to value 2548345
# Academic license 2548345 - for non-commercial use only - registered to ra___@aluno.cefetmg.br
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2548345
# Academic license 2548345 - for non-commercial use only - registered to ra___@aluno.cefetmg.br
# Set parameter TimeLimit to value 500
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 10.0 (19045.2))
#
# CPU model: AMD Ryzen 7 5800X 8-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2548345 - for non-commercial use only - registered to ra___@aluno.cefetmg.br
# Optimize a model with 774 rows, 1300 columns and 1902 nonzeros
# Model fingerprint: 0xf8422a21
# Model has 598 quadratic objective terms
# Model has 648 quadratic constraints
# Model has 25 general constraints
# Variable types: 675 continuous, 625 integer (625 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [1e+00, 4e+02]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [8e+01, 9e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
#   QRHS range       [1e+01, 1e+08]
# Presolve removed 704 rows and 149 columns
# Presolve time: 0.04s
# Presolved: 3337 rows, 3336 columns, 22495 nonzeros
# Presolved model has 1104 SOS constraint(s)
# Variable types: 2232 continuous, 1104 integer (1104 binary)
# Found heuristic solution: objective 163226.29562
#
# Root relaxation: objective 1.445723e+04, 671 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 14457.2257    0  179 163226.296 14457.2257  91.1%     -    0s
# H    0     0                    133107.96330 14457.2257  89.1%     -    0s
# H    0     0                    118447.49991 21925.5297  81.5%     -    0s
#      0     0 21925.5297    0  205 118447.500 21925.5297  81.5%     -    0s
#      0     0 21970.3551    0  213 118447.500 21970.3551  81.5%     -    0s
#      0     0 26663.2905    0  236 118447.500 26663.2905  77.5%     -    0s
#      0     0 26884.4997    0  245 118447.500 26884.4997  77.3%     -    0s
#      0     0 26885.4952    0  246 118447.500 26885.4952  77.3%     -    0s
# H    0     0                    117695.25688 26885.4952  77.2%     -    0s
#      0     0 29928.9446    0  256 117695.257 29928.9446  74.6%     -    0s
#      0     0 30116.6488    0  266 117695.257 30116.6488  74.4%     -    0s
#      0     0 32909.7430    0  279 117695.257 32909.7430  72.0%     -    0s
#      0     0 33135.4429    0  288 117695.257 33135.4429  71.8%     -    0s
#      0     0 35268.5499    0  289 117695.257 35268.5499  70.0%     -    0s
#      0     0 35352.8111    0  289 117695.257 35352.8111  70.0%     -    0s
#      0     2 35354.5185    0  289 117695.257 35354.5185  70.0%     -    0s
# H  147   148                    114491.82140 38454.5353  66.4%   138    1s
# H  193   194                    112105.28285 38454.5353  65.7%   123    1s
# H  691   702                    109100.43733 38454.5353  64.8%  84.2    3s
#   1780  1669 65668.4756  135  232 109100.437 38454.5353  64.8%  68.9    5s
#   2814  2512 62518.9245   22  324 109100.437 62518.9245  42.7%  69.7   10s
#   2910  2577 66559.4578   88  344 109100.437 64201.3428  41.2%  71.7   15s
#   2945  2610 65027.5959   29  514 109100.437 64749.9780  40.7%  76.2   20s
#   2988  2642 66877.2645   32  472 109100.437 65030.9537  40.4%  80.8   25s
# H 3009  2513                    108744.47040 65030.9537  40.2%  82.7   25s
#   3124  2608 72149.4711   40  467 108744.470 65030.9537  40.2%  89.4   30s
#   3256  2692 78830.0866   48  395 108744.470 65030.9537  40.2%  95.7   35s
#   3478  2854 84655.3225   58  307 108744.470 65030.9537  40.2%  99.4   40s
#   3753  3063 92766.9370   76  257 108744.470 65030.9537  40.2%   103   45s
#   4117  3181 65262.7074   31  509 108744.470 65031.2803  40.2%   106   50s
#   4469  3394 70018.1265   45  434 108744.470 65031.2803  40.2%   113   55s
# H 4682  3334                    108688.11461 65031.2803  40.2%   116   57s
#   4743  3401 69025.1608   60  395 108688.115 65031.2803  40.2%   118   60s
# H 4896  3419                    107425.12838 65031.2803  39.5%   121   62s
#   5070  3535 72293.5546   79  380 107425.128 65031.2803  39.5%   123   65s
#   5678  3947 94436.9881  113  217 107425.128 65031.2803  39.5%   125   71s
#   6209  4287 67080.9341   41  447 107425.128 65965.1023  38.6%   125   75s
# H 6838  4310                    106953.20328 65965.1023  38.3%   125   78s
#   6841  4403 72999.2066   61  390 106953.203 65965.1023  38.3%   125   80s
#   7641  4967 78375.7019   90  353 106953.203 65965.1023  38.3%   125   85s
# H 7794  4795                    106440.85170 65965.1023  38.0%   124   85s
#   8423  5510 89421.2201  160  283 106440.852 65965.1023  38.0%   124   90s
#   9623  6200 87686.2424   82  363 106440.852 66344.5857  37.7%   120   96s
#  10313  6603 82829.1639   75  333 106440.852 66452.9066  37.6%   119  100s
# H10427  6603                    106433.42102 66452.9066  37.6%   119  100s
#  11879  7872 77384.2002   60  355 106433.421 66500.2167  37.5%   115  107s
#  13173  9453 77254.1360   87  351 106433.421 66643.8566  37.4%   111  111s
#  14179 10755 75035.9804   62  383 106433.421 66656.9710  37.4%   110  115s
#  15922 11817 76262.6216  110  327 106433.421 66656.9710  37.4%   107  121s
#  17084 13398 88851.8138  124  285 106433.421 66861.2878  37.2%   106  125s
#  18945 14561 71208.4920   44  430 106433.421 66941.6489  37.1%   104  131s
#  21333 16725 72251.1033   48  413 106433.421 67072.6104  37.0%   102  137s
#  22055 16976 72683.4642   58  392 106433.421 67139.5779  36.9%   101  140s
#  24078 18881 84804.3124  158  322 106433.421 67142.6168  36.9%   101  146s
#  24600 19151 88745.9246  170  330 106433.421 67142.6168  36.9%   102  153s
#  24846 19500 95006.0450  174  310 106433.421 67184.5012  36.9%   103  156s
#  25643 21204 69746.2866   47  426 106433.421 67195.6334  36.9%   104  161s
#  27557 22047 73680.9193   61  359 106433.421 67222.3673  36.8%   105  168s
#  28100 22290 85289.0784   77  266 106433.421 67222.3673  36.8%   106  171s
#  28795 23757 89421.2414  120  233 106433.421 67231.9689  36.8%   107  176s
#  31227 25233 78364.0858   70  331 106433.421 67325.7972  36.7%   106  183s
#  31960 26175 80870.1134   75  292 106433.421 67336.6964  36.7%   106  185s
#  33849 28178 75016.2092   72  352 106433.421 67394.6557  36.7%   104  190s
#  35922 29056 90088.1997  114  276 106433.421 67430.1978  36.6%   103  196s
#  37765 30838 76957.8554   61  347 106433.421 67505.5175  36.6%   103  201s
#  38286 31099 75211.7125   70  358 106433.421 67505.5175  36.6%   103  205s
# H38605 31414                    106141.97582 67505.5175  36.4%   103  207s
#  38996 32535 80368.6939   99  323 106141.976 67505.5175  36.4%   104  210s
#  41241 33604 94511.7192  155  252 106141.976 67505.5175  36.4%   104  216s
# H41591 33426                    104936.85549 67505.5175  35.7%   104  216s
#  41594 33676 96305.1614  158  268 104936.855 67505.5175  35.7%   104  220s
#  43325 35405 72272.7847   50  410 104936.855 67622.7941  35.6%   104  227s
#  43967 36047     cutoff  158      104936.855 67631.5096  35.6%   104  231s
#  44673 36439 93918.0737  143  244 104936.855 67645.6264  35.5%   104  235s
#  46936 38440 69532.7175   42  398 104936.855 67742.3586  35.4%   103  240s
#  48203 40236 82312.6568   44  368 104936.855 67746.5941  35.4%   103  245s
#  50347 41301 72854.9018   45  409 104936.855 67822.7317  35.4%   102  251s
#  52586 43362     cutoff  174      104936.855 67867.4677  35.3%   101  255s
#  53830 44536 84228.3645  161  290 104936.855 67884.0297  35.3%   101  260s
# H54779 44720                    104721.56857 67901.0299  35.2%   101  263s
#  54967 45078 78387.3042  105  300 104721.569 67901.0299  35.2%   101  266s
#  55893 46653 87706.4786  144  250 104721.569 67902.8904  35.2%   102  270s
# H56385 46503                    104370.61842 67902.8904  34.9%   102  270s
#  57829 47455     cutoff  170      104370.618 67923.4693  34.9%   102  276s
#  58774 48298 84093.4428  102  309 104370.618 67935.6383  34.9%   102  282s
#  60994 50371 82111.3511   93  347 104370.618 67974.2758  34.9%   101  287s
#  61597 51008 71639.5209   59  420 104370.618 67980.1825  34.9%   101  290s
#  62942 52785 94899.3342  127  311 104370.618 68005.2420  34.8%   100  295s
#  64962 53853 94232.2415   74  186 104370.618 68036.6654  34.8%   100  300s
#  67004 55310 93712.4563  103  352 104370.618 68058.5711  34.8%   100  305s
#  67694 56369 98115.5466  112  315 104370.618 68085.2842  34.8%   100  311s
#  68940 57834 69280.3383   69  411 104370.618 68106.1738  34.7%   100  316s
#  70731 58631 84018.9446  119  293 104370.618 68106.1738  34.7%   100  323s
#  71420 58996 91919.1429  144  286 104370.618 68106.1738  34.7%   100  327s
#  71855 59222     cutoff  157      104370.618 68127.7784  34.7%   100  330s
#  73809 61274     cutoff  168      104370.618 68158.5173  34.7%   100  336s
#  74518 61726 78938.6848  121  350 104370.618 68172.3489  34.7%   100  340s
#  75989 63025 78771.0678  105  373 104370.618 68203.9177  34.7%   100  346s
#  76583 63446 97448.6665  161  269 104370.618 68203.9177  34.7%   100  350s
#  77036 64028     cutoff  172      104370.618 68211.4067  34.6%   100  355s
#  77673 64348 infeasible  167      104370.618 68220.0588  34.6%   100  360s
#  79604 66476 77233.5591   98  362 104370.618 68262.6935  34.6%  99.3  365s
#  81456 67768 78298.0209  106  378 104370.618 68262.6935  34.6%  99.1  372s
#  82193 68088 79152.4042  110  359 104370.618 68262.6935  34.6%  99.0  377s
#  82569 69187 79586.2247  114  382 104370.618 68307.6823  34.6%  99.1  380s
#  84366 69984 95386.5106  132  304 104370.618 68319.9183  34.5%  99.4  387s
#  86112 71437 75451.4053   63  388 104370.618 68370.3372  34.5%  99.4  392s
#  86662 72135 82047.3838   85  365 104370.618 68382.3842  34.5%  99.4  395s
#  88037 73956 92637.7202  125  323 104370.618 68411.6836  34.5%  99.4  401s
#  90136 74963 78295.6719   91  398 104370.618 68430.9601  34.4%   100  407s
#  90691 75430 82308.6082  134  353 104370.618 68430.9601  34.4%   100  411s
#  91226 75771 97501.0101  197  260 104370.618 68441.8424  34.4%   100  415s
#  92830 77180 68878.6781   47  392 104370.618 68468.5400  34.4%   100  420s
#  93740 77954 82482.5992   50  310 104370.618 68470.8631  34.4%   101  428s
#  94227 78449 78761.0326   63  340 104370.618 68470.8631  34.4%   101  431s
#  96448 80281 78967.7597   92  342 104370.618 68501.1453  34.4%   101  437s
#  96964 80597 72800.3219   48  436 104370.618 68506.2400  34.4%   101  441s
#  98906 82617 77161.1561   60  372 104370.618 68521.4751  34.3%   101  446s
#  99730 82840 83589.6982   97  340 104370.618 68548.5084  34.3%   101  450s
#  101000 84049 70874.9965   48  387 104370.618 68555.2425  34.3%   101  455s
#  101725 84593 72837.7198   42  437 104370.618 68570.1878  34.3%   102  463s
#  101954 85857 75131.9322   48  384 104370.618 68570.6769  34.3%   102  465s
#  103931 86693 75062.7768   36  394 104370.618 68596.8555  34.3%   102  472s
#  104532 87203 76084.4840   79  393 104370.618 68606.0351  34.3%   102  475s
#  106414 88793 84647.6522  130  317 104370.618 68638.7951  34.2%   102  480s
#  108057 90699 92913.5461  154  273 104370.618 68671.3780  34.2%   102  486s
#  109339 91328 95022.8953  158  331 104370.618 68687.9137  34.2%   102  490s
#  111260 92996     cutoff  171      104370.618 68711.5495  34.2%   102  496s
#  113442 94620 74539.3790   66  337 104370.618 68741.2336  34.1%   102  500s
#
# Cutting planes:
#   Gomory: 51
#   Cover: 23
#   Implied bound: 499
#   Projected implied bound: 6
#   MIR: 167
#   Flow cover: 322
#   Inf proof: 2
#   Zero half: 1
#   RLT: 31
#   Relax-and-lift: 107
#
# Explored 113753 nodes (11583355 simplex iterations) in 500.05 seconds (804.45 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 10: 104371 104722 104937 ... 108744
#
# Time limit reached
# Best objective 1.043706184232e+05, best bound 6.874123361254e+04, gap 34.1374%

# %%
for var in model.getVars():
    if(var.x > 0):
        print(f"{var.varName} = {var.x}")


#print solution objective value
print(f"Objetivo: {model.objVal}")
# Out:
# x[0,1] = 1.0
# x[0,3] = 1.0
# x[0,4] = 1.0
# x[0,6] = 1.0
# x[0,7] = 1.0
# x[0,8] = 1.0
# x[0,14] = 1.0
# x[0,15] = 1.0
# x[1,2] = 1.0
# x[2,24] = 1.0
# x[3,5] = 1.0
# x[4,10] = 1.0
# x[5,11] = 1.0
# x[6,22] = 1.0
# x[7,13] = 1.0
# x[8,9] = 1.0
# x[9,20] = 1.0
# x[10,12] = 1.0
# x[11,24] = 1.0
# x[12,24] = 1.0
# x[13,19] = 1.0
# x[14,17] = 1.0
# x[15,16] = 1.0
# x[16,18] = 1.0
# x[17,23] = 1.0
# x[18,24] = 1.0
# x[19,24] = 1.0
# x[20,24] = 1.0
# x[21,24] = 1.0
# x[22,21] = 1.0
# x[23,24] = 1.0
# omega[1] = 30.0
# omega[2] = 20.0
# omega[3] = 40.0
# omega[4] = 40.0
# omega[5] = 30.0
# omega[6] = 40.0
# omega[7] = 40.0
# omega[8] = 40.0
# omega[9] = 30.0
# omega[10] = 30.0
# omega[11] = 20.0
# omega[12] = 20.0
# omega[13] = 30.0
# omega[14] = 40.0
# omega[15] = 40.0
# omega[16] = 30.0
# omega[17] = 30.0
# omega[18] = 20.0
# omega[19] = 20.0
# omega[20] = 20.0
# omega[21] = 20.0
# omega[22] = 30.0
# omega[23] = 20.0
# omega[24] = 10.0
# e[0,0] = 140000000.0
# e[0,1] = 139996469.41931126
# e[0,2] = 140000000.0
# e[0,3] = 139994971.2824694
# e[0,4] = 139992965.7978429
# e[0,5] = 140000000.0
# e[0,6] = 139991252.33745432
# e[0,7] = 139993521.3581672
# e[0,8] = 139991478.49778518
# e[0,9] = 140000000.0
# e[0,10] = 140000000.0
# e[0,11] = 140000000.0
# e[0,12] = 140000000.0
# e[0,13] = 140000000.0
# e[0,14] = 139992384.22689432
# e[0,15] = 139994919.52758116
# e[0,16] = 140000000.0
# e[0,17] = 140000000.0
# e[0,18] = 140000000.0
# e[0,19] = 140000000.0
# e[0,20] = 140000000.0
# e[0,21] = 140000000.0
# e[0,22] = 140000000.0
# e[0,23] = 140000000.0
# e[0,24] = 140000000.0
# e[1,0] = 139996469.41931126
# e[1,1] = 139996469.41931126
# e[1,2] = 139995473.02581468
# e[1,3] = 139996469.41931126
# e[1,4] = 139996469.41931126
# e[1,5] = 139996469.41931126
# e[1,6] = 139996469.41931126
# e[1,7] = 139996469.41931126
# e[1,8] = 139996469.41931126
# e[1,9] = 139996469.41931126
# e[1,10] = 139996469.41931126
# e[1,11] = 139996469.41931126
# e[1,12] = 139996469.41931126
# e[1,13] = 139996469.41931126
# e[1,14] = 139996469.41931126
# e[1,15] = 139996469.41931126
# e[1,16] = 139996469.41931126
# e[1,17] = 139996469.41931126
# e[1,18] = 139996469.41931126
# e[1,19] = 139996469.41931126
# e[1,20] = 139996469.41931126
# e[1,21] = 139996469.41931126
# e[1,22] = 139996469.41931126
# e[1,23] = 139996469.41931126
# e[1,24] = 139996469.41931126
# e[2,0] = 139995473.02581468
# e[2,1] = 139995473.02581468
# e[2,2] = 139995473.02581468
# e[2,3] = 139995473.02581468
# e[2,4] = 139995473.02581468
# e[2,5] = 139995473.02581468
# e[2,6] = 139995473.02581468
# e[2,7] = 139995473.02581468
# e[2,8] = 139995473.02581468
# e[2,9] = 139995473.02581468
# e[2,10] = 139995473.02581468
# e[2,11] = 139995473.02581468
# e[2,12] = 139995473.02581468
# e[2,13] = 139995473.02581468
# e[2,14] = 139995473.02581468
# e[2,15] = 139995473.02581468
# e[2,16] = 139995473.02581468
# e[2,17] = 139995473.02581468
# e[2,18] = 139995473.02581468
# e[2,19] = 139995473.02581468
# e[2,20] = 139995473.02581468
# e[2,21] = 139995473.02581468
# e[2,22] = 139995473.02581468
# e[2,23] = 139995473.02581468
# e[2,24] = 139994001.9717708
# e[3,0] = 139994971.2824694
# e[3,1] = 139994971.2824694
# e[3,2] = 139994971.2824694
# e[3,3] = 139994971.2824694
# e[3,4] = 139994971.2824694
# e[3,5] = 139992678.68568832
# e[3,6] = 139994971.2824694
# e[3,7] = 139994971.2824694
# e[3,8] = 139994971.2824694
# e[3,9] = 139994971.2824694
# e[3,10] = 139994971.2824694
# e[3,11] = 139994971.2824694
# e[3,12] = 139994971.2824694
# e[3,13] = 139994971.2824694
# e[3,14] = 139994971.2824694
# e[3,15] = 139994971.2824694
# e[3,16] = 139994971.2824694
# e[3,17] = 139994971.2824694
# e[3,18] = 139994971.2824694
# e[3,19] = 139994971.2824694
# e[3,20] = 139994971.2824694
# e[3,21] = 139994971.28246945
# e[3,22] = 139994971.28246945
# e[3,23] = 139994971.28246957
# e[3,24] = 139994971.2824692
# e[4,0] = 139992965.7978429
# e[4,1] = 139992965.7978429
# e[4,2] = 139992965.7978429
# e[4,3] = 139992965.7978429
# e[4,4] = 139992965.7978429
# e[4,5] = 139992965.7978429
# e[4,6] = 139992965.7978429
# e[4,7] = 139992965.7978429
# e[4,8] = 139992965.7978429
# e[4,9] = 139992965.7978429
# e[4,10] = 139989844.35586843
# e[4,11] = 139992965.7978429
# e[4,12] = 139992965.7978429
# e[4,13] = 139992965.7978429
# e[4,14] = 139992965.7978429
# e[4,15] = 139992965.7978429
# e[4,16] = 139992965.7978429
# e[4,17] = 139992965.7978429
# e[4,18] = 139992965.7978429
# e[4,19] = 139992965.7978429
# e[4,20] = 139992965.7978429
# e[4,21] = 139992965.7978429
# e[4,22] = 139992965.7978429
# e[4,23] = 139992965.7978429
# e[4,24] = 139992965.7978429
# e[5,0] = 139992678.68568832
# e[5,1] = 139992678.68568832
# e[5,2] = 139992678.68568832
# e[5,3] = 139992678.68568832
# e[5,4] = 139992678.68568832
# e[5,5] = 139992678.68568832
# e[5,6] = 139992678.68568832
# e[5,7] = 139992678.68568832
# e[5,8] = 139992678.68568832
# e[5,9] = 139992678.68568832
# e[5,10] = 139992678.68568832
# e[5,11] = 139991378.5318512
# e[5,12] = 139992678.68568832
# e[5,13] = 139992678.68568832
# e[5,14] = 139992678.68568832
# e[5,15] = 139992678.68568832
# e[5,16] = 139992678.68568832
# e[5,17] = 139992678.68568832
# e[5,18] = 139992678.68568832
# e[5,19] = 139992678.68568832
# e[5,20] = 139992678.68568832
# e[5,21] = 139992678.68568832
# e[5,22] = 139992678.68568832
# e[5,23] = 139992678.68568832
# e[5,24] = 139992678.68568832
# e[6,0] = 139991252.33745432
# e[6,1] = 139991252.33745432
# e[6,2] = 139991252.33745432
# e[6,3] = 139991252.33745432
# e[6,4] = 139991252.33745432
# e[6,5] = 139991252.33745432
# e[6,6] = 139991252.33745432
# e[6,7] = 139991252.33745432
# e[6,8] = 139991252.33745432
# e[6,9] = 139991252.33745432
# e[6,10] = 139991252.33745432
# e[6,11] = 139991252.33745432
# e[6,12] = 139991252.33745432
# e[6,13] = 139991252.33745432
# e[6,14] = 139991252.33745432
# e[6,15] = 139991252.33745432
# e[6,16] = 139991252.33745432
# e[6,17] = 139991252.33745432
# e[6,18] = 139991252.33745432
# e[6,19] = 139991252.33745432
# e[6,20] = 139991252.33745432
# e[6,21] = 139991252.33745432
# e[6,22] = 139986529.3616973
# e[6,23] = 139991252.33745432
# e[6,24] = 139991252.33745387
# e[7,0] = 139993521.3581672
# e[7,1] = 139993521.3581672
# e[7,2] = 139993521.3581672
# e[7,3] = 139993521.3581672
# e[7,4] = 139993521.3581672
# e[7,5] = 139993521.3581672
# e[7,6] = 139993521.3581672
# e[7,7] = 139993521.3581672
# e[7,8] = 139993521.3581672
# e[7,9] = 139993521.3581672
# e[7,10] = 139993521.3581672
# e[7,11] = 139993521.3581672
# e[7,12] = 139993521.3581672
# e[7,13] = 139990537.60214502
# e[7,14] = 139993521.3581672
# e[7,15] = 139993521.3581672
# e[7,16] = 139993521.3581672
# e[7,17] = 139993521.3581672
# e[7,18] = 139993521.3581672
# e[7,19] = 139993521.3581672
# e[7,20] = 139993521.3581672
# e[7,21] = 139993521.3581672
# e[7,22] = 139993521.3581672
# e[7,23] = 139993521.3581672
# e[7,24] = 139993521.3581672
# e[8,0] = 139991478.49778518
# e[8,1] = 139991478.49778518
# e[8,2] = 139991478.49778518
# e[8,3] = 139991478.49778518
# e[8,4] = 139991478.49778518
# e[8,5] = 139991478.49778518
# e[8,6] = 139991478.49778518
# e[8,7] = 139991478.49778518
# e[8,8] = 139991478.49778518
# e[8,9] = 139989736.94675234
# e[8,10] = 139991478.49778518
# e[8,11] = 139991478.49778518
# e[8,12] = 139991478.49778518
# e[8,13] = 139991478.49778518
# e[8,14] = 139991478.49778518
# e[8,15] = 139991478.49778518
# e[8,16] = 139991478.49778518
# e[8,17] = 139991478.49778518
# e[8,18] = 139991478.49778518
# e[8,19] = 139991478.49778518
# e[8,20] = 139991478.49778518
# e[8,21] = 139991478.49778518
# e[8,22] = 139991478.49778518
# e[8,23] = 139991478.49778518
# e[8,24] = 139991478.49778518
# e[9,0] = 139989736.94675234
# e[9,1] = 139989736.94675234
# e[9,2] = 139989736.94675234
# e[9,3] = 139989736.94675234
# e[9,4] = 139989736.94675234
# e[9,5] = 139989736.94675234
# e[9,6] = 139989736.94675234
# e[9,7] = 139989736.94675234
# e[9,8] = 139989736.94675234
# e[9,9] = 139989736.94675234
# e[9,10] = 139989736.94675234
# e[9,11] = 139989736.94675234
# e[9,12] = 139989736.94675234
# e[9,13] = 139989736.94675234
# e[9,14] = 139989736.94675234
# e[9,15] = 139989736.94675234
# e[9,16] = 139989736.94675234
# e[9,17] = 139989736.94675234
# e[9,18] = 139989736.94675234
# e[9,19] = 139989736.94675234
# e[9,20] = 139988910.145688
# e[9,21] = 139989736.94675234
# e[9,22] = 139989736.94675234
# e[9,23] = 139989736.94675234
# e[9,24] = 139989736.94675234
# e[10,0] = 139989844.35586843
# e[10,1] = 139989844.35586843
# e[10,2] = 139989844.35586843
# e[10,3] = 139989844.35586843
# e[10,4] = 139989844.35586843
# e[10,5] = 139989844.35586843
# e[10,6] = 139989844.35586843
# e[10,7] = 139989844.35586843
# e[10,8] = 139989844.35586843
# e[10,9] = 139989844.35586843
# e[10,10] = 139989844.35586843
# e[10,11] = 139989844.35586843
# e[10,12] = 139988594.07589978
# e[10,13] = 139989844.35586843
# e[10,14] = 139989844.35586843
# e[10,15] = 139989844.35586843
# e[10,16] = 139989844.35586843
# e[10,17] = 139989844.35586843
# e[10,18] = 139989844.35586843
# e[10,19] = 139989844.35586843
# e[10,20] = 139989844.35586843
# e[10,21] = 139989844.35586843
# e[10,22] = 139989844.35586843
# e[10,23] = 139989844.35586843
# e[10,24] = 139989844.35586843
# e[11,0] = 139991378.53185114
# e[11,1] = 139991378.53185114
# e[11,2] = 139991378.53185114
# e[11,3] = 139991378.53185114
# e[11,4] = 139991378.53185114
# e[11,5] = 139991378.53185114
# e[11,6] = 139991378.53185114
# e[11,7] = 139991378.53185114
# e[11,8] = 139991378.53185114
# e[11,9] = 139991378.53185114
# e[11,10] = 139991378.53185114
# e[11,11] = 139991378.53185114
# e[11,12] = 139991378.53185114
# e[11,13] = 139991378.53185114
# e[11,14] = 139991378.53185114
# e[11,15] = 139991378.53185114
# e[11,16] = 139991378.53185114
# e[11,17] = 139991378.53185114
# e[11,18] = 139991378.53185114
# e[11,19] = 139991378.53185114
# e[11,20] = 139991378.53185114
# e[11,21] = 139991378.53185114
# e[11,22] = 139991378.53185114
# e[11,23] = 139991378.53185114
# e[11,24] = 139988733.06402862
# e[12,0] = 139988594.07589978
# e[12,1] = 139988594.07589978
# e[12,2] = 139988594.07589978
# e[12,3] = 139988594.07589978
# e[12,4] = 139988594.07589978
# e[12,5] = 139988594.07589978
# e[12,6] = 139988594.07589978
# e[12,7] = 139988594.07589978
# e[12,8] = 139988594.07589978
# e[12,9] = 139988594.07589978
# e[12,10] = 139988594.07589978
# e[12,11] = 139988594.07589978
# e[12,12] = 139988594.07589978
# e[12,13] = 139988594.07589978
# e[12,14] = 139988594.07589978
# e[12,15] = 139988594.07589978
# e[12,16] = 139988594.07589978
# e[12,17] = 139988594.07589978
# e[12,18] = 139988594.07589978
# e[12,19] = 139988594.07589978
# e[12,20] = 139988594.07589978
# e[12,21] = 139988594.07589978
# e[12,22] = 139988594.07589978
# e[12,23] = 139988594.07589978
# e[12,24] = 139985473.29074216
# e[13,0] = 139990537.60214502
# e[13,1] = 139990537.60214502
# e[13,2] = 139990537.60214502
# e[13,3] = 139990537.60214502
# e[13,4] = 139990537.60214502
# e[13,5] = 139990537.60214502
# e[13,6] = 139990537.60214502
# e[13,7] = 139990537.60214502
# e[13,8] = 139990537.60214502
# e[13,9] = 139990537.60214502
# e[13,10] = 139990537.60214502
# e[13,11] = 139990537.60214502
# e[13,12] = 139990537.60214502
# e[13,13] = 139990537.60214502
# e[13,14] = 139990537.60214502
# e[13,15] = 139990537.60214502
# e[13,16] = 139990537.60214502
# e[13,17] = 139990537.60214502
# e[13,18] = 139990537.60214502
# e[13,19] = 139988814.34940672
# e[13,20] = 139990537.60214502
# e[13,21] = 139990537.60214502
# e[13,22] = 139990537.60214502
# e[13,23] = 139990537.60214502
# e[13,24] = 139990537.60214502
# e[14,0] = 139992384.22689432
# e[14,1] = 139992384.22689432
# e[14,2] = 139992384.22689432
# e[14,3] = 139992384.22689432
# e[14,4] = 139992384.22689432
# e[14,5] = 139992384.22689432
# e[14,6] = 139992384.22689432
# e[14,7] = 139992384.22689432
# e[14,8] = 139992384.22689432
# e[14,9] = 139992384.22689432
# e[14,10] = 139992384.22689432
# e[14,11] = 139992384.22689432
# e[14,12] = 139992384.22689432
# e[14,13] = 139992384.22689432
# e[14,14] = 139992384.22689432
# e[14,15] = 139992384.22689432
# e[14,16] = 139992384.22689432
# e[14,17] = 139989558.16957006
# e[14,18] = 139992384.2268937
# e[14,19] = 139992384.22689432
# e[14,20] = 139992384.22689432
# e[14,21] = 139992384.22689432
# e[14,22] = 139992384.22689432
# e[14,23] = 139992384.22689432
# e[14,24] = 139992384.22689432
# e[15,0] = 139994919.52758116
# e[15,1] = 139994919.52758116
# e[15,2] = 139994919.52758116
# e[15,3] = 139994919.52758116
# e[15,4] = 139994919.52758116
# e[15,5] = 139994919.52758116
# e[15,6] = 139994919.52758116
# e[15,7] = 139994919.52758116
# e[15,8] = 139994919.52758116
# e[15,9] = 139994919.52758116
# e[15,10] = 139994919.52758116
# e[15,11] = 139994919.52758116
# e[15,12] = 139994919.52758116
# e[15,13] = 139994919.52758116
# e[15,14] = 139994919.52758116
# e[15,15] = 139994919.52758116
# e[15,16] = 139993228.5811006
# e[15,17] = 139994919.52758116
# e[15,18] = 139994919.52758116
# e[15,19] = 139994919.52758116
# e[15,20] = 139994919.52758116
# e[15,21] = 139994919.52758116
# e[15,22] = 139994919.52758116
# e[15,23] = 139994919.52758116
# e[15,24] = 139994919.52758116
# e[16,0] = 139993228.5811006
# e[16,1] = 139993228.5811006
# e[16,2] = 139993228.5811006
# e[16,3] = 139993228.5811006
# e[16,4] = 139993228.5811006
# e[16,5] = 139993228.5811006
# e[16,6] = 139993228.5811006
# e[16,7] = 139993228.5811006
# e[16,8] = 139993228.5811006
# e[16,9] = 139993228.5811006
# e[16,10] = 139993228.5811006
# e[16,11] = 139993228.5811006
# e[16,12] = 139993228.5811006
# e[16,13] = 139993228.5811006
# e[16,14] = 139993228.5811006
# e[16,15] = 139993228.5811006
# e[16,16] = 139993228.5811006
# e[16,17] = 139993228.5811006
# e[16,18] = 139991967.15333733
# e[16,19] = 139993228.5811006
# e[16,20] = 139993228.5811006
# e[16,21] = 139993228.5811006
# e[16,22] = 139993228.5811006
# e[16,23] = 139993228.5811006
# e[16,24] = 139993228.5811006
# e[17,0] = 139989558.16956937
# e[17,1] = 139989558.16956937
# e[17,2] = 139989558.16956937
# e[17,3] = 139989558.16956937
# e[17,4] = 139989558.16956937
# e[17,5] = 139989558.16956937
# e[17,6] = 139989558.16956937
# e[17,7] = 139989558.16956937
# e[17,8] = 139989558.16956937
# e[17,9] = 139989558.16956937
# e[17,10] = 139989558.16956937
# e[17,11] = 139989558.16956937
# e[17,12] = 139989558.16956937
# e[17,13] = 139989558.16956937
# e[17,14] = 139989558.16956937
# e[17,15] = 139989558.16956937
# e[17,16] = 139989558.16956937
# e[17,17] = 139989558.16956937
# e[17,18] = 139989558.16956937
# e[17,19] = 139989558.16956937
# e[17,20] = 139989558.16956937
# e[17,21] = 139989558.16956937
# e[17,22] = 139989558.16956937
# e[17,23] = 139988049.52779594
# e[17,24] = 139989558.16956934
# e[18,0] = 139991967.15333727
# e[18,1] = 139991967.15333727
# e[18,2] = 139991967.15333727
# e[18,3] = 139991967.15333727
# e[18,4] = 139991967.15333727
# e[18,5] = 139991967.15333727
# e[18,6] = 139991967.15333727
# e[18,7] = 139991967.15333727
# e[18,8] = 139991967.15333727
# e[18,9] = 139991967.15333727
# e[18,10] = 139991967.15333727
# e[18,11] = 139991967.15333727
# e[18,12] = 139991967.15333727
# e[18,13] = 139991967.15333727
# e[18,14] = 139991967.15333727
# e[18,15] = 139991967.15333727
# e[18,16] = 139991967.15333727
# e[18,17] = 139991967.15333727
# e[18,18] = 139991967.15333727
# e[18,19] = 139991967.15333727
# e[18,20] = 139991967.15333727
# e[18,21] = 139991967.15333727
# e[18,22] = 139991967.15333727
# e[18,23] = 139991967.15333727
# e[18,24] = 139989540.77743894
# e[19,0] = 139988814.34940672
# e[19,1] = 139988814.34940672
# e[19,2] = 139988814.34940672
# e[19,3] = 139988814.34940672
# e[19,4] = 139988814.34940672
# e[19,5] = 139988814.34940672
# e[19,6] = 139988814.34940672
# e[19,7] = 139988814.34940672
# e[19,8] = 139988814.34940672
# e[19,9] = 139988814.34940672
# e[19,10] = 139988814.34940672
# e[19,11] = 139988814.34940672
# e[19,12] = 139988814.34940672
# e[19,13] = 139988814.34940672
# e[19,14] = 139988814.34940672
# e[19,15] = 139988814.34940672
# e[19,16] = 139988814.34940672
# e[19,17] = 139988814.34940672
# e[19,18] = 139988814.34940672
# e[19,19] = 139988814.34940672
# e[19,20] = 139988814.34940672
# e[19,21] = 139988814.34940672
# e[19,22] = 139988814.34940672
# e[19,23] = 139988814.34940672
# e[19,24] = 139985426.8872298
# e[20,0] = 139988910.145688
# e[20,1] = 139988910.145688
# e[20,2] = 139988910.145688
# e[20,3] = 139988910.145688
# e[20,4] = 139988910.145688
# e[20,5] = 139988910.145688
# e[20,6] = 139988910.145688
# e[20,7] = 139988910.145688
# e[20,8] = 139988910.145688
# e[20,9] = 139988910.145688
# e[20,10] = 139988910.145688
# e[20,11] = 139988910.145688
# e[20,12] = 139988910.145688
# e[20,13] = 139988910.145688
# e[20,14] = 139988910.145688
# e[20,15] = 139988910.145688
# e[20,16] = 139988910.145688
# e[20,17] = 139988910.145688
# e[20,18] = 139988910.145688
# e[20,19] = 139988910.145688
# e[20,20] = 139988910.145688
# e[20,21] = 139988910.145688
# e[20,22] = 139988910.145688
# e[20,23] = 139988910.145688
# e[20,24] = 139985806.6959945
# e[21,0] = 139985205.57923764
# e[21,1] = 139985205.57923764
# e[21,2] = 139985205.57923764
# e[21,3] = 139985205.57923764
# e[21,4] = 139985205.57923764
# e[21,5] = 139985205.57923764
# e[21,6] = 139985205.57923764
# e[21,7] = 139985205.57923764
# e[21,8] = 139985205.57923764
# e[21,9] = 139985205.57923764
# e[21,10] = 139985205.57923764
# e[21,11] = 139985205.57923764
# e[21,12] = 139985205.57923764
# e[21,13] = 139985205.57923764
# e[21,14] = 139985205.57923764
# e[21,15] = 139985205.57923764
# e[21,16] = 139985205.57923764
# e[21,17] = 139985205.57923764
# e[21,18] = 139985205.57923764
# e[21,19] = 139985205.57923764
# e[21,20] = 139985205.57923764
# e[21,21] = 139985205.57923764
# e[21,22] = 139985205.57923764
# e[21,23] = 139985205.57923764
# e[21,24] = 139980925.29887298
# e[22,0] = 139986529.36169723
# e[22,1] = 139986529.36169723
# e[22,2] = 139986529.36169723
# e[22,3] = 139986529.36169723
# e[22,4] = 139986529.36169723
# e[22,5] = 139986529.36169723
# e[22,6] = 139986529.36169723
# e[22,7] = 139986529.36169723
# e[22,8] = 139986529.36169723
# e[22,9] = 139986529.36169723
# e[22,10] = 139986529.36169723
# e[22,11] = 139986529.36169723
# e[22,12] = 139986529.36169723
# e[22,13] = 139986529.36169723
# e[22,14] = 139986529.36169723
# e[22,15] = 139986529.36169723
# e[22,16] = 139986529.36169723
# e[22,17] = 139986529.36169723
# e[22,18] = 139986529.36169723
# e[22,19] = 139986529.36169723
# e[22,20] = 139986529.36169723
# e[22,21] = 139985205.5792377
# e[22,22] = 139986529.36169723
# e[22,23] = 139986529.36169723
# e[22,24] = 139986529.36169717
# e[23,0] = 139988049.52779576
# e[23,1] = 139988049.52779576
# e[23,2] = 139988049.52779576
# e[23,3] = 139988049.52779576
# e[23,4] = 139988049.52779576
# e[23,5] = 139988049.52779576
# e[23,6] = 139988049.52779576
# e[23,7] = 139988049.52779576
# e[23,8] = 139988049.52779576
# e[23,9] = 139988049.52779576
# e[23,10] = 139988049.52779576
# e[23,11] = 139988049.52779576
# e[23,12] = 139988049.52779576
# e[23,13] = 139988049.52779576
# e[23,14] = 139988049.52779576
# e[23,15] = 139988049.52779576
# e[23,16] = 139988049.52779576
# e[23,17] = 139988049.52779576
# e[23,18] = 139988049.52779576
# e[23,19] = 139988049.52779576
# e[23,20] = 139988049.52779576
# e[23,21] = 139988049.52779576
# e[23,22] = 139988049.52779576
# e[23,23] = 139988049.52779576
# e[23,24] = 139985721.3954971
# e[24,0] = 1119895629.3815749
# e[24,1] = 1119895629.3815749
# e[24,2] = 1119895629.3815749
# e[24,3] = 1119895629.3815749
# e[24,4] = 1119895629.3815749
# e[24,5] = 1119895629.3815749
# e[24,6] = 1119895629.3815749
# e[24,7] = 1119895629.3815749
# e[24,8] = 1119895629.3815749
# e[24,9] = 1119895629.3815749
# e[24,10] = 1119895629.3815749
# e[24,11] = 1119895629.3815749
# e[24,12] = 1119895629.3815749
# e[24,13] = 1119895629.3815749
# e[24,14] = 1119895629.3815749
# e[24,15] = 1119895629.3815749
# e[24,16] = 1119895629.3815749
# e[24,17] = 1119895629.3815749
# e[24,18] = 1119895629.3815749
# e[24,19] = 1119895629.3815749
# e[24,20] = 1119895629.3815749
# e[24,21] = 1119895629.3815749
# e[24,22] = 1119895629.3815749
# e[24,23] = 1119895629.3815749
# e[24,24] = 1119895629.3815749
# omega_power_beta[1] = 30.0
# omega_power_beta[2] = 20.0
# omega_power_beta[3] = 40.0
# omega_power_beta[4] = 40.0
# omega_power_beta[5] = 30.0
# omega_power_beta[6] = 40.0
# omega_power_beta[7] = 40.0
# omega_power_beta[8] = 40.0
# omega_power_beta[9] = 30.0
# omega_power_beta[10] = 30.0
# omega_power_beta[11] = 20.0
# omega_power_beta[12] = 20.0
# omega_power_beta[13] = 30.0
# omega_power_beta[14] = 40.0
# omega_power_beta[15] = 40.0
# omega_power_beta[16] = 30.0
# omega_power_beta[17] = 30.0
# omega_power_beta[18] = 20.0
# omega_power_beta[19] = 20.0
# omega_power_beta[20] = 20.0
# omega_power_beta[21] = 20.0
# omega_power_beta[22] = 30.0
# omega_power_beta[23] = 20.0
# omega_power_beta[24] = 10.0
# Objetivo: 104370.6184231761

# %%
subroutes = []
goesTo = {}
for var in model.getVars():
    if var.VarName[0] == 'x' and var.x > 0:
        #print(f"{var.VarName} = {var.x}")
        x,y = var.VarName.split('[')[1].split(']')[0].split(',')
        x = int(x)
        y = int(y)
        if x == base_start:
            subroutes.append([y])
        else:
            goesTo[x] = y

for i in range(len(subroutes)):
    next = goesTo[subroutes[i][-1]]
    while next != base_end:
        subroutes[i].append(next)
        next = goesTo[next]

print(subroutes)
route = []
for subroute in subroutes:
    route += subroute
    route.append(0)
route.pop()
print(route)
print(model.ObjVal)
# Out:
# [[1, 2], [3, 5, 11], [4, 10, 12], [6, 22, 21], [7, 13, 19], [8, 9, 20], [14, 17, 23], [15, 16, 18]]
# [1, 2, 0, 3, 5, 11, 0, 4, 10, 12, 0, 6, 22, 21, 0, 7, 13, 19, 0, 8, 9, 20, 0, 14, 17, 23, 0, 15, 16, 18]
# 104370.6184231761
